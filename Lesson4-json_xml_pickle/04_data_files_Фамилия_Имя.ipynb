# %% [markdown]
# # Форматы данных (1)

# %% [markdown]
# Материалы:
# * Макрушин С.В. "Лекция 4: Форматы данных"
# * https://docs.python.org/3/library/json.html
# * https://docs.python.org/3/library/pickle.html
# * https://www.crummy.com/software/BeautifulSoup/bs4/doc.ru/bs4ru.html
# * Уэс Маккини. Python и анализ данных

# %%
import csv
import json
import pickle
import pandas as pd
import numpy as np

from bs4 import BeautifulSoup as bs
from pprint import pprint as pp

# %%
# with open("./data/data/addres-book.json", 'r', encoding="UTF-8") as fp:
#     json_data = json.load(fp)

# with open("./data/data/addres-book.pickle", 'br') as fp:
#     pickle_data = pickle.load(fp)

# with open("./data/data/addres-book-q.xml", 'r') as fp:
#     bs_data = BeautifulSoup(fp, 'lxml')

# %%
# bs_data

# %%
# for address in bs_data.find_all("address"):
#     for phone in address.find_all("phone"):
#         print(phone)

# %% [markdown]
# ## Задачи для совместного разбора

# %% [markdown]
# 1. Вывести все адреса электронной почты, содержащиеся в адресной книге `addres-book.json`

# %% [markdown]
# 2. Вывести телефоны, содержащиеся в адресной книге `addres-book.json`

# %% [markdown]
# 3. По данным из файла `addres-book-q.xml` сформировать список словарей с телефонами каждого из людей.

# %% [markdown]
# ## Лабораторная работа №4

# %% [markdown]
# ### JSON

# %% [markdown]
# 1.1 Считайте файл `contributors_sample.json`. Воспользовавшись модулем `json`, преобразуйте содержимое файла в соответствующие объекты python. Выведите на экран информацию о первых 3 пользователях.

# %%
with open("./data/data/contributors_sample.json", 'r', encoding="UTF-8") as fp:
    contributors_sample_json = json.load(fp)

pp(contributors_sample_json[:3])
# Out:
# [{'address': '01261 Cameron Spring\nTaylorfurt, AK 97791',
#   'id': 35193,
#   'jobs': ['Energy engineer',
#            'Engineer, site',
#            'Environmental health practitioner',
#            'Biomedical scientist',
#            'Jewellery designer'],
#   'mail': 'jsalazar@gmail.com',
#   'name': 'Lindsey Nguyen',
#   'sex': 'F',
#   'username': 'uhebert'},
#  {'address': '66992 Welch Brooks\nMarshallshire, ID 56004',
#   'id': 91970,
#   'jobs': ['Music therapist',
#            'Volunteer coordinator',
#            'Designer, interior/spatial'],
#   'mail': 'bhudson@gmail.com',
#   'name': 'Cheryl Lewis',
#   'sex': 'F',
#   'username': 'vickitaylor'},
#  {'address': 'Unit 1632 Box 2971\nDPO AE 23297',
#   'id': 1848091,
#   'jobs': ['Management consultant',
#            'Engineer, structural',
#            'Lecturer, higher education',
#            'Theatre manager',
#            'Designer, textile'],
#   'mail': 'darren44@yahoo.com',
#   'name': 'Julia Allen',
# ...

# %% [markdown]
# 1.2 Выведите уникальные почтовые домены, содержащиеся в почтовых адресах людей

# %%
mail_domains = []
for persons in contributors_sample_json:
    domain = persons["mail"].split("@")[1]
    if domain not in mail_domains:
        mail_domains.append(domain)

mail_domains
# Out:
# ['gmail.com', 'yahoo.com', 'hotmail.com']

# %% [markdown]
# 1.3 Напишите функцию, которая по `username` ищет человека и выводит информацию о нем. Если пользователь с заданным `username` отсутствует, возбудите исключение `ValueError`

# %%
def find(name):
    for person in contributors_sample_json:
        if person["username"] == name:
            return person
    raise ValueError("Invalid name")

# %%
pp(find("vickitaylor"))
# Out:
# {'address': '66992 Welch Brooks\nMarshallshire, ID 56004',
#  'id': 91970,
#  'jobs': ['Music therapist',
#           'Volunteer coordinator',
#           'Designer, interior/spatial'],
#  'mail': 'bhudson@gmail.com',
#  'name': 'Cheryl Lewis',
#  'sex': 'F',
#  'username': 'vickitaylor'}

# %%
# pp(find("test"))

# %% [markdown]
# 1.4 Посчитайте, сколько мужчин и женщин присутсвует в этом наборе данных.

# %%
num_of_males = 0
num_of_females = 0
for person in contributors_sample_json:
    if person["sex"] == "M":
        num_of_males += 1
    elif person["sex"] == "F":
        num_of_females += 1

num_of_females, num_of_males
# Out:
# (2136, 2064)

# %% [markdown]
# 1.5 Создайте `pd.DataFrame` `contributors`, имеющий столбцы `id`, `username` и `sex`.

# %%
contributors = pd.DataFrame(contributors_sample_json).drop(columns=['address', 'mail', 'jobs', 'name'])
contributors
# Out:
#            username sex       id
# 0           uhebert   F    35193
# 1       vickitaylor   F    91970
# 2       sheilaadams   F  1848091
# 3          nicole82   F    50969
# 4            jean67   M   676820
# ...             ...  ..      ...
# 4195  stevenspencer   F   423555
# 4196      rwilliams   M    35251
# 4197      lmartinez   F   135887
# 4198     brendahill   M   212714
# 4199       mistyray   F   344321
#
# [4200 rows x 3 columns]

# %% [markdown]
# 1.6 Загрузите данные из файла `recipes_sample.csv` (__ЛР2__) в таблицу `recipes`. Объедините `recipes` с таблицей `contributors` с сохранением строк в том случае, если информация о человеке отсутствует в JSON-файле. Для скольких человек информация отсутствует?

# %%
recipes_sample = pd.read_csv("./data/data/recipes_sample.csv")
recipes_sample = recipes_sample.merge(contributors, how="outer", left_on="contributor_id", right_on="id")
print(recipes_sample["id_y"].isna().sum())
recipes_sample
# Out:
# 15059
#                                          name    id_x  minutes  \
# 0       george s at the cove  black bean soup   44123       90
# 1      allegedly original cobb salad dressing   39189        5
# 2                     basic cake  gluten free   52100       55
# 3                         basil garlic butter   32311       15
# 4                       beer marinated shrimp   36315      125
# ...                                       ...     ...      ...
# 29995                         zucchini strips  279769       30
# 29996      zucchini with bacon corn   peppers  326105       45
# 29997    zucchini with bell pepper and tomato  363362       13
# 29998               zucchini with serrano ham  162411       15
# 29999                zucchini potato pancakes  180833       45
#
#        contributor_id   submitted  n_steps  \
# 0               35193  2002-10-25      NaN
# 1               35193  2002-09-03      3.0
# 2               35193  2003-01-24      NaN
# ...

# %% [markdown]
# ### pickle

# %% [markdown]
# 2.1 На основе файла `contributors_sample.json` создайте словарь следующего вида:
# ```
# {
#     должность: [список username людей, занимавших эту должность]
# }
# ```

# %%
with open("data/data/contributors_sample.pickle", 'wb') as file:
    pickle.dump(contributors_sample_json, file)


with open("./data/data/contributors_sample.pickle", "rb") as pfile:
    contributors_sample_pickle = pickle.load(pfile)

# %%
job_list = {}
for peoples in contributors_sample_pickle:
   jobs = peoples["jobs"]
   for job in jobs:
        if job not in job_list:
            job_list[job] = []
        job_list[job].append(peoples["name"])


job_list
# Out:
# {'Energy engineer': ['Lindsey Nguyen',
#   'Richard Brown',
#   'Frank Cruz',
#   'Anna Yu',
#   'Brenda Young',
#   'Carrie Harris',
#   'Lauren Jones',
#   'Bernard Houston',
#   'Debra Berry',
#   'Joseph Davis',
#   'Emily Martin DDS',
#   'Kimberly Rodriguez',
#   'Bryce Martinez',
#   'Felicia Conley',
#   'Jessica Villarreal',
#   'Jessica Villarreal',
#   'Natalie Cline',
#   'Samantha Miller',
#   'Sandra Williamson',
#   'John Ritter',
#   'Christopher Lewis',
#   'Shannon Johnson'],
#  'Engineer, site': ['Lindsey Nguyen',
#   'Jesus Thomas',
#   'Noah Garcia',
#   'Autumn Parker',
#   'Katie James',
#   'Ashley Gill',
#   'Ashley Martin',
#   'Adam Short',
#   'Jonathan Sheppard',
#   'Teresa Novak',
#   'Jillian Knapp',
#   'Emily Williams',
#   'Alexander Becker',
#   'Bryan Casey',
#   'William Sandoval',
#   'Christopher Price',
#   'Noah Harper',
#   'Grace Day',
#   'Eric Smith',
#   'Samuel West',
#   'Chelsey Mitchell',
#   'Patricia Gross',
# ...

# %% [markdown]
# 2.2 Сохраните результаты в файл `job_people.pickle` и в файл `job_people.json` с использованием форматов pickle и JSON соответственно. Сравните объемы получившихся файлов. При сохранении в JSON укажите аргумент `indent`.

# %%
with open("./data/data/job_people.pickle", "wb") as f:
    pickle.dump(job_list, f)

with open("./data/data/job_people.json", "w") as f:
    json.dump(job_list, f)

# %% [markdown]
# 2.3 Считайте файл `job_people.pickle` и продемонстрируйте, что данные считались корректно.

# %%
with open("./data/data/job_people.pickle", "rb") as f:
    p_job_people = pickle.load(f)

pp(p_job_people)
# Out:
# {'Academic librarian': ['Amy Durham',
#                         'Tim Hayes',
#                         'Mary Ellis',
#                         'Kristina Wang',
#                         'Anthony Reeves',
#                         'Gabriel Moore',
#                         'Nichole Cross',
#                         'Jim Wells',
#                         'Gregory Gregory',
#                         'Katelyn Smith',
#                         'Megan Adams',
#                         'Angela Kennedy',
#                         'Chris Villanueva',
#                         'Christopher Morales',
#                         'John Sullivan',
#                         'Christina Kane',
#                         'Lisa Ruiz',
#                         'Patricia Smith'],
#  'Accommodation manager': ['Leslie Padilla',
#                            'Scott Ramos',
#                            'Kristopher Clarke',
#                            'Nancy Watkins',
# ...

# %% [markdown]
# ### XML

# %% [markdown]
# 3.1 По данным файла `steps_sample.xml` сформируйте словарь с шагами по каждому рецепту вида `{id_рецепта: ["шаг1", "шаг2"]}`. Сохраните этот словарь в файл `steps_sample.json`

# %%
with open("D:\Programming\Python\BigDataPT-BDPT-\Lesson4-json_xml_pickle\data\data\steps_sample.xml", "r", encoding="UTF-8") as f:
    steps_sample_xml = bs(f, "xml")

# %%
dict_one = {}
for recipe in steps_sample_xml.recipes.find_all("recipe"):
    if recipe.id.text not in dict_one:
        dict_one[recipe.id.text] = [] #recipe.find_all("steps")
    for steps in recipe.find_all("step"):
        dict_one[recipe.id.text].append(steps.text)
dict_one
# Out:
# {'44123': ['in 1 / 4 cup butter , saute carrots , onion , celery and broccoli stems for 5 minutes',
#   'add thyme , oregano and basil',
#   'saute 5 minutes more',
#   'add wine and deglaze pan',
#   'add hot chicken stock and reduce by one-third',
#   'add worcestershire sauce , tabasco , smoked chicken , beans and broccoli florets',
#   'simmer 5 minutes',
#   'add cream , simmer 5 minutes more and season to taste',
#   'drop in remaining butter , piece by piece , stirring until melted and serve immediately',
#   'smoked chicken: on a covered grill , slightly smoke boneless chicken , cooking to medium rare',
#   'chef meskan uses applewood chips and does not allow the grill to become too hot'],
#  '67664': ['mix all the ingredients using a blender',
#   'pour into popsicle molds',
#   'freeze and enjoy !'],
#  '38798': ['combine all ingredients in a large bowl and mix well',
#   'shape into one-inch balls',
#   'cover and refrigerate or freeze until ready to bake',
# ...

# %%
import json

with open("./data/data/steps_sample.json", "w") as j_file:
    json.dump(dict_one, j_file)

# %% [markdown]
# 3.2 По данным файла `steps_sample.xml` сформируйте словарь следующего вида: `кол-во_шагов_в_рецепте: [список_id_рецептов]`

# %%
dict_two = {}
for recipes in steps_sample_xml.recipes.find_all("recipe"):
    if len(recipes.steps) not in dict_two:
        dict_two[len(recipes.steps)] = []
    dict_two[len(recipes.steps)].append(recipes.find("id").text)

pp(dict_two)
# Out:
# {3: ['33246',
#      '125721',
#      '8827',
#      '281241',
#      '351371',
#      '455529',
#      '485158',
#      '276396',
#      '67666',
#      '284868',
#      '229602',
#      '323477',
#      '112725',
#      '275046',
#      '512016',
#      '404419',
#      '61105',
#      '213993',
#      '269631',
#      '269186',
#      '23353',
#      '153053',
#      '10633',
#      '367819',
#      '14450',
#      '45544',
#      '21332',
#      '207929',
#      '306297',
#      '215579',
#      '286717',
#      '245056',
#      '150063',
#      '141231',
#      '171900',
#      '377604',
#      '156521',
#      '219708',
#      '257358',
#      '299621',
#      '121166',
#      '507169',
#      '40568',
#      '459993',
#      '246787',
#      '377416',
#      '260015',
#      '71746',
#      '366389',
#      '255007',
#      '310004',
#      '14782',
#      '53106',
#      '7697',
#      '195792',
#      '269776',
#      '297839',
#      '257710',
#      '462416',
# ...

# %% [markdown]
# 3.3 Получите список рецептов, в этапах выполнения которых есть информация о времени (часы или минуты). Для отбора подходящих рецептов обратите внимание на атрибуты соответствующих тэгов.

# %%
recipes_list_with_time = []
for recipe in steps_sample_xml.recipes.find_all("recipe"):
    if recipe.find("step", attrs={'has_minutes': '1'}) or recipe.find("step", attrs={'has_hours': "1"}):
        recipes_list_with_time.append(recipe.id.text)

recipes_list_with_time
# Out:
# ['44123',
#  '35173',
#  '453467',
#  '306168',
#  '50662',
#  '118843',
#  '149593',
#  '200148',
#  '310570',
#  '95534',
#  '109818',
#  '66932',
#  '226001',
#  '141939',
#  '250883',
#  '120297',
#  '223349',
#  '60938',
#  '302399',
#  '342620',
#  '296983',
#  '129581',
#  '325714',
#  '487173',
#  '447429',
#  '137701',
#  '63346',
#  '342619',
#  '383120',
#  '463219',
#  '39172',
#  '216068',
#  '173730',
#  '287778',
#  '437637',
#  '123115',
#  '371549',
#  '376813',
#  '390230',
#  '401605',
#  '306590',
#  '299968',
#  '192542',
#  '147563',
#  '193719',
#  '38852',
#  '250232',
#  '437219',
#  '77380',
#  '21357',
#  '198343',
#  '129919',
#  '375376',
#  '63131',
#  '24760',
#  '375362',
#  '217296',
#  '435816',
#  '198073',
#  '202949',
#  '367828',
#  '140610',
#  '392181',
#  '468143',
#  '176996',
#  '290187',
#  '459738',
#  '111198',
#  '33246',
#  '302498',
#  '165438',
#  '267159',
#  '401283',
#  '428566',
#  '533190',
#  '478546',
#  '40228',
#  '255985',
# ...

# %% [markdown]
# 3.4 Загрузите данные из файла `recipes_sample.csv` (__ЛР2__) в таблицу `recipes`. Для строк, которые содержат пропуски в столбце `n_steps`, заполните этот столбец на основе файла  `steps_sample.xml`. Строки, в которых столбец `n_steps` заполнен, оставьте без изменений.

# %%
recipes_sample = pd.read_csv("../Pandas/data/data/recipes_sample.csv", sep=",")
recipes_sample[:100]
# Out:
#                                         name      id  minutes  contributor_id  \
# 0      george s at the cove  black bean soup   44123       90           35193
# 1         healthy for them  yogurt popsicles   67664       10           91970
# 2               i can t believe it s spinach   38798       30            1533
# 3                       italian  gut busters   35173       45           22724
# 4   love is in the air  beef fondue   sauces   84797       25            4470
# ..                                       ...     ...      ...             ...
# 95    1 point plus   hg s faux fried pickles  459738       40          120566
# 96                         1 001 nights cake  111198       50           94272
# 97                      1 1 1 tempura batter  164636        5          236760
# 98                               1 2 3 bread   33246       55           47549
# 99                          1 2 3 enchiladas  302498       20          454149
#
# ...

# %%
for recipe in steps_sample_xml.recipes.find_all("recipe"):
    recipe_id = int(recipe.id.text)
    if np.isnan(recipes_sample[recipes_sample["id"] == recipe_id]["n_steps"].iloc[0]):
        recipes_sample.loc[recipes_sample.id == recipe_id, "n_steps"] = len(recipe.find_all("step"))

recipes_sample[:100]
# Out:
#                                         name      id  minutes  contributor_id  \
# 0      george s at the cove  black bean soup   44123       90           35193
# 1         healthy for them  yogurt popsicles   67664       10           91970
# 2               i can t believe it s spinach   38798       30            1533
# 3                       italian  gut busters   35173       45           22724
# 4   love is in the air  beef fondue   sauces   84797       25            4470
# ..                                       ...     ...      ...             ...
# 95    1 point plus   hg s faux fried pickles  459738       40          120566
# 96                         1 001 nights cake  111198       50           94272
# 97                      1 1 1 tempura batter  164636        5          236760
# 98                               1 2 3 bread   33246       55           47549
# 99                          1 2 3 enchiladas  302498       20          454149
#
# ...

# %% [markdown]
# 3.5 Проверьте, содержит ли столбец `n_steps` пропуски. Если нет, то преобразуйте его к целочисленному типу и сохраните результаты в файл `recipes_sample_with_filled_nsteps.csv`

# %%
pp(np.sum(np.isnan(recipes_sample["n_steps"])))
recipes_sample["n_steps"] = recipes_sample["n_steps"].astype("Int64")
recipes_sample.head()
# Out:
# 0
#                                        name     id  minutes  contributor_id  \
# 0     george s at the cove  black bean soup  44123       90           35193
# 1        healthy for them  yogurt popsicles  67664       10           91970
# 2              i can t believe it s spinach  38798       30            1533
# 3                      italian  gut busters  35173       45           22724
# 4  love is in the air  beef fondue   sauces  84797       25            4470
#
#     submitted  n_steps                                        description  \
# 0  2002-10-25       11  an original recipe created by chef scott meska...
# 1  2003-07-26        3  my children and their friends ask for my homem...
# 2  2002-08-29        5            these were so go, it surprised even me.
# 3  2002-07-27        7  my sister-in-law made these for us at a family...
# 4  2004-02-23        4  i think a fondue is a very romantic casual din...
#
#    n_ingredients
# 0           18.0
# 1            NaN
# ...

# %%
recipes_sample.to_csv("./data/data/recipes_sample_with_filled_nsteps.csv")
